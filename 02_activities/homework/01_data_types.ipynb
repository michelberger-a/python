# %% [markdown]
# # Getting Started: Python Fundamentals
# ## Practice Problems

# %% [markdown]
# ### 1. What types are involved in the following expressions? What data type will each expression evaluate to?
#
# `8 * 2.5`

# %%
# Your code here
#8 = int
#2.5 = float
#8*2.5 = float
type(8*2.5)
# Out:
# float

# %% [markdown]
# `9 / 2`

# %%
# Your code here
# both are ints
# will evaluate to float
type(9/2)
# Out:
# float

# %% [markdown]
# `9 // -2`

# %%
# Your code here
#both numbers and the output evaluate to int
type(9//-2)
# Out:
# int

# %% [markdown]
# `1.5 * 2 >= 7 - 3`

# %%
# Your code here

#valuates to boolean

# %% [markdown]
# ### 2. In which order will the expressions be evaluated.
#
# `6 * 3 + 7 * 4`
#
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `*` > `+`
# </details>
#
#
# `5 - 2 * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `**` > `*` > `-`
# </details>
#
# `(5 - 2) * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `(-)` > `**` > `*`
# </details>
#
# `5 + 2 >= 3 * 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `+` > `>=`
# </details>

# %%
# first goes 6*3, 7*4, +
# second goes, 3**4, 2*3, 5-
# third goes (5-2), 3**4, *
#fourth goes 3*4, 5+2, >=
