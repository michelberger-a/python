# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here
print('''
This little line of mine... I'm gonna let it runnnn  
This little line of mine... I'm gonna let it runnnnn 
Let it run, let it run, let it runnnnnnnn  
''')
# Out:
# This little line of mine... I'm gonna let it runnnn
# This little line of mine... I'm gonna let it runnnnn
# Let it run, let it run, let it runnnnnnnn

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here
string1 = 'words here'

# %%
string1.append('word')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 string1.append('word')
#
# AttributeError: 'str' object has no attribute 'append'
