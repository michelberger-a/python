# %% [markdown]
# # NumPy
# ## Practice Problems

# %% [markdown]
# ### 1. The formula for exponential growth is `population_size = N0 *e**rt`, where `N0` is the initial population, `e` is the exponential function, `r` is the rate, and `t` is time. Using this:
#
# 1.   Set the initial population, `N0`, as 100 and the growth rate, `r`, as 0.4
# 2.   Use the suitable `numpy` function to generate an array of time points, `t`, which go from 0 to 10 seconds, in 0.2 second increments.
# 3.   Write an expression to evaluate `population_size`, which should be an array of the population size for each time point in `t`.
# 4.   Create a new variable called `population_size_noise`, use the same expression you wrote in parts (3), and add noise to the population at each time point. Do this by adding an expression that uses a `numpy` function to generate a random value for each time point drawn from a normal distribution of `mean=0` and `stdev=250` (i.e., population_size_noise = expression_from_part_a + expression_to_add_noise).

# %%
# Your code here
import numpy as np
N0 = 100
r = 0.4
t = np.arange(0, 10.2, 0.2)

# %%
population_size = N0 * np.exp(r*t)
population_size
# Out:
# array([ 100.        ,  108.32870677,  117.3510871 ,  127.12491503,
#         137.71277643,  149.18246976,  161.60744022,  175.06725003,
#         189.64808793,  205.44332106,  222.55409285,  241.08997064,
#         261.16964734,  282.92170144,  306.48542033,  332.01169227,
#         359.66397256,  389.61933018,  422.0695817 ,  457.22251951,
#         495.30324244,  536.55559711,  581.24373944,  629.6538261 ,
#         682.09584693,  738.90560989,  800.44689143,  867.11376585,
#         939.33312874, 1017.56743061, 1102.31763806, 1194.12644178,
#        1293.58173155, 1401.32036077, 1518.0322245 , 1644.46467711,
#        1781.42731796, 1929.79717555, 2090.52432351, 2264.63796432,
#        2453.25301971, 2657.57726999, 2878.91908792, 3118.69581683,
#        3378.44284638, 3659.82344437, 3964.63940726, 4294.84259788,
#        4652.54744398, 5040.04447781, 5459.81500331])

# %%
# add noise to the expression
population_size_noise = population_size + np.random.normal(loc=0, scale=250, size = np.shape(population_size))
print("Population size with noise is: ", population_size_noise)
# Out:
# Population size with noise is:  [ 326.52063093   50.05643976  211.5137159   152.36621507  174.10192872
#   644.02424451  495.67266312  482.73882948  272.74408687  152.89374918
#  -283.993648    480.87371405  197.99924194  595.19920055  524.47982346
#   125.41756197  527.36070837  868.48019166  679.4634153   278.59599816
#   328.02886238  946.64795063  438.72611556  380.32396113  883.07181114
#  1034.77023432  379.71583846  619.70014618  939.28000219  866.20624095
#  1052.89573791  864.46035522 1822.19796905 1180.26717899 1642.11590048
#  1870.60886385 1478.53856691 2148.22083412 1896.53021755 2469.49216031
#  2836.85079027 2827.30984584 2861.40665565 2869.1042214  3623.97128424
#  3171.07019172 3825.89756788 3960.19277481 4564.46298169 5288.13144218
#  5475.24978382]

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   import numpy as np
#
#   #set initial population
#   N0 = 100
#   #set growth rate
#   rate = 0.4
#   #create array of time points
#   t = np.arange(start=0, stop=10.2, step=0.2)
#
#   #calculate population of colony at the time points in t
#   population_size = N0 * np.exp(rate*t)
#   print('Population size is: ',population_size)
#
#   #add noise to population at each time point
#   population_size_noise = N0 * np.exp(rate*t) + np.random.normal(loc=0, scale=250, size=np.shape(population_size))
#   print('Population size with noise is: ',population_size_noise)
#   ```
# </details>

# %% [markdown]
# ### 2. Create a multiplication table for the number 6.

# %%
# Your code here
six = np.arange(0, 13, 1)
six = six * 6
six

rows = np.arange(1,7)
columns = rows[:, np.newaxis] # this sort of transposes the array to a column
arr = rows * columns
print(arr)
# Out:
# [[ 1  2  3  4  5  6]
#  [ 2  4  6  8 10 12]
#  [ 3  6  9 12 15 18]
#  [ 4  8 12 16 20 24]
#  [ 5 10 15 20 25 30]
#  [ 6 12 18 24 30 36]]

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   rows = np.arange(1, 7)
#   columns = rows[:,np.newaxis]
#   arr = rows * columns
#   arr
#   ```
# </details>

# %% [markdown]
# ### 3. Slice `arr` to create the following two arrays:
#
# `arr1` = [4, 12, 3]
#
# `arr2` = [3, 19]

# %%
# Your code here
print(arr)
print([arr[0,3],arr[1,5],arr[2,0]])
print([arr[0,2], arr[0,2]+16])
# Out:
# [[ 1  2  3  4  5  6]
#  [ 2  4  6  8 10 12]
#  [ 3  6  9 12 15 18]
#  [ 4  8 12 16 20 24]
#  [ 5 10 15 20 25 30]
#  [ 6 12 18 24 30 36]]
# [4, 12, 3]
# [3, 19]

# %%
  arr = np.array([[4, 12, 98], [12, 11, 92], [3, 19, 60]])
  print(arr)

  arr1 = arr[:,0]
  print(arr1)

  arr2 = arr[2,0:2]
  print(arr2)
# Out:
# [[ 4 12 98]
#  [12 11 92]
#  [ 3 19 60]]
# [ 4 12  3]
# [ 3 19]

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   arr = np.array([[4, 12, 98], [12, 11, 92], [3, 19, 60]])
#   arr
#
#   arr1 = arr[:,0]
#   print(arr1)
#
#   arr2 = arr[2,0:2]
#   print(arr2)
#   ```
# </details>
