# %% [markdown]
# # Object Oriented Programming
# ## Practice Problems

# %% [markdown]
# ### 1. Create a class called `Book` that has the attributes `title`, `author`, `pages`, `price`. It also has the method `get_price()` which returns `price`. Then create two instances of this class:
#
# - `b1`:
# `title` -> 'Practical Programming...'
# `author` -> 'Gries, Campbell, Montojo'
# `pages` -> 383
# `price` -> 50
#
# - `b2`:
# `title` -> 'Building a Career in Data Science'
# `author` -> 'Robinson, Nolis'
# `pages` -> 322
# `price` -> 40

# %%
# Your code goes here
class Book:
  def __init__(self, title, author, pages, price):
    self.title = title
    self.author = author
    self.pages = pages
    self._price = price

  def get_price(self):
    return self.price

  b1 = Book('Practical Programming...', 'Gries, Campbell, Montojo', 383, 50)
  b2 = Book('Building a Career in Data Science', 'Robinson, Nolis', 322, 40)


  print(b1.get_price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Your code goes here
# ----> 2 class Book:
#       3   def __init__(self, title, author, pages, price):
#       4     self.title = title
#
# Cell In[20], line 16, in Book()
#      12 b1 = Book('Practical Programming...', 'Gries, Campbell, Montojo', 383, 50)
#      13 b2 = Book('Building a Career in Data Science', 'Robinson, Nolis', 322, 40)
# ---> 16 print(b1.get_price)
#
# AttributeError: 'Book' object has no attribute 'get_price'

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   class Book:
#   def __init__(self, title, author, pages, price):
#     self.title = title
#     self.author = author
#     self.pages = pages
#     self.price = price
#
#   def get_price(self):
#     return self.price
#
#   b1 = Book('Practical Programming...', 'Gries, Campbell, Montojo', 383, 50)
#   b2 = Book('Building a Career in Data Science', 'Robinson, Nolis', 322, 40)
#
#   print(b1.getprice())
#   ```
# </details>

# %% [markdown]
# ### 2. Create a `Phone` class that has the attributes `model`, `id`, `name`, `brand` and `price`. Create the getters and setters for each attribute. As well as the following methods: `calculate_total` which takes the price and calculates it by the tax argument.

# %%
# Your code goes here

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   class Phone:
#     def __init__(self, model, id, name, brand, price):
#       self._model = model
#       self._id = id
#       self._name = name
#       self._brand = brand
#       self._price = price
#
#     def calculate_total(self, tax):
#       return self._price * tax
#
#   phone = Phone("15 Pro Max", 1, "iPhone", "Apple", 1599)
#   print(phone.calculate_total(1.13))
#   ```
# </details>
